# %%
# %reload_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
from echo_finder import get_echos
from fft_implementation import get_fft_list
from file_helper import load_data_points, get_time_domain_data_without_offset, check_NaN_in_dataFrame
from utility import get_distance
from LoadData import LoadData

# %%
l = LoadData('bigCobbleStoneVertical', 80)

# %%
# Out:
#         1         2         3         4         5         6         7      \
# 0    0.003174  0.004028  0.003906  0.004395  0.005127  0.005127  0.005493
# 1    0.008423  0.008545  0.008911  0.009644  0.009766  0.009766  0.009766
# 2    0.006104  0.006226  0.006470  0.007080  0.007202  0.007690  0.008301
# 3    0.006714  0.006836  0.006836  0.007080  0.007446  0.007324  0.007202
# 4    0.006470  0.007080  0.007324  0.007202  0.006958  0.006470  0.006714
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.006104  0.006470  0.007080  0.007568  0.008301  0.008545  0.008911
# 496  0.008057  0.008545  0.009033  0.009277  0.009277  0.009399  0.009644
# 497  0.004517  0.004761  0.004761  0.005249  0.005615  0.006470  0.007568
# 498  0.004272  0.004883  0.005371  0.006348  0.006470  0.006836  0.006958
# 499  0.005005  0.005859  0.006714  0.006714  0.007202  0.007568  0.007812
#
#         8         9         10     ...     16375     16376     16377  \
# 0    0.006348  0.006592  0.006714  ... -0.003540 -0.003662 -0.002930
# 1    0.009888  0.010254  0.010254  ...  0.005981  0.005493  0.005127
# 2    0.007812  0.007690  0.007935  ...  0.007324  0.005249  0.000854
# 3    0.006592  0.006714  0.006836  ...  0.006104  0.008789  0.008789
# 4    0.006836  0.006836  0.007568  ...  0.003052  0.001587  0.000488
# ..        ...       ...       ...  ...       ...       ...       ...
# 495  0.008545  0.008667  0.008179  ...  0.005737  0.006104  0.007446
# 496  0.009766  0.009521  0.009277  ...  0.007690  0.009521  0.009888
# 497  0.007690  0.006958  0.006592  ...  0.011108  0.004395 -0.000244
# 498  0.006714  0.006836  0.006836  ...  0.001831  0.000244  0.000122
# 499  0.007568  0.007324  0.006836  ...  0.005005  0.008301  0.010010
#
#         16378     16379     16380     16381     16382     16383     16384
# 0   -0.002930 -0.002441 -0.001587 -0.001587 -0.003906 -0.006226 -0.004272
# 1    0.003540  0.001465 -0.001099 -0.002319 -0.002563  0.000366  0.003540
# 2   -0.002563 -0.002441  0.001709  0.005615  0.009644  0.009277  0.004517
# 3    0.007568  0.006958  0.006348  0.007568  0.006470  0.006714  0.008301
# 4    0.000488  0.003540  0.004883  0.004517  0.003784  0.003540  0.004395
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.009888  0.013428  0.014282  0.014648  0.013306  0.009277  0.005859
# 496  0.009888  0.010254  0.010986  0.013428  0.015991  0.017578  0.017212
# 497 -0.002686 -0.000610  0.001587  0.001221  0.000610 -0.001343 -0.000854
# 498  0.001587  0.002319  0.003784  0.004272  0.001465 -0.002197 -0.003906
# 499  0.010376  0.009399  0.007690  0.005249  0.004395  0.003540  0.001099
#
# [500 rows x 16384 columns]

# %%
d = l.data[0]['initialFilteredData'][0]
get_distance(d, plot=True)
# Out:
# 86.02642089093703

# %%
for i in range(0,5):
    d = l.data[i]['initialFilteredData'][1]
    d = get_distance(d)
    print(l.data[i]['distance'], d)
# Out:
# 80 72.14664618535586
# 90 95.0799795186892
# 100 102.1431643625192
# 110 129.56804915514593
# 120 119.44004096262161

# %%
d = l.data[0]['initialFilteredData'][1]
d = get_distance(d, plot=True)
